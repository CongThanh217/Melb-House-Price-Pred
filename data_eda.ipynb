# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



df = pd.read_csv("Data_clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      Suburb    Address  Rooms Type      Price Method SellerG  \
# 0           1  Abbotsford  Bloomburg      2    h  1035000.0      S  Biggin
# 1           2  Abbotsford    Charles      3    h  1465000.0     SP  Biggin
# 2           4  Abbotsford       Park      4    h  1600000.0     VB  Nelson
# 3           6  Abbotsford      Yarra      3    h  1876000.0      S  Nelson
# 4           7  Abbotsford    Charles      2    h  1636000.0      S  Nelson
#
#    Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0  2016       2.5  ...       1.0  0.0     156.0          79.0     1900.0
# 1  2017       2.5  ...       2.0  0.0     134.0         150.0     1900.0
# 2  2016       2.5  ...       1.0  2.0     120.0         142.0     2014.0
# 3  2016       2.5  ...       2.0  0.0     245.0         210.0     1910.0
# 4  2016       2.5  ...       1.0  2.0     256.0         107.0     1890.0
#
#    CouncilArea  Lattitude Longtitude             Regionname  Propertycount
# ...

# %%
df_cat = df[['Suburb', 'Address', 'Type', 'Method', 'SellerG', "Date", "YearBuilt", "CouncilArea", "Regionname", "Postcode"]]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts().head(20)
    print("Graph for {}, total = {}".format(i, len(cat_num)))
    plt.barh(cat_num.index, cat_num, color ='maroon')
    plt.show()
# Out:
# Graph for Suburb, total = 20
# Graph for Address, total = 20
# Graph for Type, total = 3
# Graph for Method, total = 5
# Graph for SellerG, total = 20
# Graph for Date, total = 2
# Graph for YearBuilt, total = 20
# Graph for CouncilArea, total = 20
# Graph for Regionname, total = 8
# Graph for Postcode, total = 20

# %%
# df['Date'] = pd.to_datetime(df['Date'])
# # Extract year, month, and day from the date
# df['Year'] = df['Date'].dt.year
# df['Month'] = df['Date'].dt.month
# df['Day'] = df['Date'].dt.day
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Plotting price over time
# plt.figure(figsize=(14, 7))
# sns.lineplot(x='Date', y='Price', data=df)
# plt.title('Price over Time')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.show()

# # Boxplot of price by year
# plt.figure(figsize=(14, 7))
# sns.boxplot(x='Year', y='Price', data=df)
# plt.title('Price Distribution by Year')
# plt.xlabel('Year')
# plt.ylabel('Price')
# plt.show()

# # Boxplot of price by month
# plt.figure(figsize=(14, 7))
# sns.boxplot(x='Month', y='Price', data=df)
# plt.title('Price Distribution by Month')
# plt.xlabel('Month')
# plt.ylabel('Price')
# plt.show()

# correlation_year = df['Year'].corr(df['Price'])
# correlation_month = df['Month'].corr(df['Price'])
# correlation_day = df['Day'].corr(df['Price'])

# print(f"Correlation between Year and Price: {correlation_year}")
# print(f"Correlation between Month and Price: {correlation_month}")
# print(f"Correlation between Day and Price: {correlation_day}")

# # Alternatively, perform regression analysis
# import statsmodels.api as sm

# # Using Year, Month, and Day as predictors for Price
# X = df[['Year', 'Month', 'Day']]
# X = sm.add_constant(X)  # Adds a constant term to the predictor
# y = df['Price']

# model = sm.OLS(y, X).fit()
# print(model.summary())

# %%
df["Distance"].hist()
# Out:
# <Axes: >

# %%
df["Rooms"].hist()
# Out:
# <Axes: >

# %%
df["Postcode"].hist()
# Out:
# <Axes: >

# %%
df["Bedroom2"].hist()
# Out:
# <Axes: >

# %%
df["Bathroom"].hist()
# Out:
# <Axes: >

# %%
df["Car"].hist()
# Out:
# <Axes: >

# %%
df["Landsize"].hist()
# Out:
# <Axes: >

# %%
df["BuildingArea"].hist()
# Out:
# <Axes: >

# %%
df["YearBuilt"].hist()
# Out:
# <Axes: >

# %%
# Turn year built to age 
df["YearBuilt"] = df["YearBuilt"].apply(lambda x: 2024 - x)
df["YearBuilt"].hist()
# Out:
# <Axes: >

# %%
df["Propertycount"].hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.boxplot(column = ['Rooms', 'Bedroom2', 'Bathroom', 'Car'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['Distance'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['YearBuilt'])
# Out:
# <Axes: >

# %%
df.boxplot(column = ['Landsize', "BuildingArea"])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
sns.heatmap(df[['Rooms','Distance', 'Postcode', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Propertycount', 'Price']].corr(),cmap="crest", annot=True)
# Out:
# <Axes: >

# %%
# check multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

X = df[['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Propertycount', 'Price']]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns

vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]

print(vif_data)
# Out:
#          feature         VIF
# 0          Rooms  125.837679
# 1       Distance    4.965405
# 2       Bedroom2  121.841102
# 3       Bathroom   11.620347
# 4            Car    5.047949
# 5       Landsize    1.310947
# 6   BuildingArea    6.513922
# 7      YearBuilt    3.847593
# 8  Propertycount    3.122735
# 9          Price    7.580279

# %%
# drop Bedroom2, longitude, lattitude
df.drop(["Bedroom2", "Lattitude", "Longtitude"], axis=1, inplace=True)

# %%
df.drop(["Postcode"], axis=1, inplace=True)

# %%
df.drop(["CouncilArea", "Propertycount"], axis=1, inplace=True)

# %%
df
# Out:
#       Unnamed: 0        Suburb    Address  Rooms Type      Price Method  \
# 0              1    Abbotsford  Bloomburg      2    h  1035000.0      S
# 1              2    Abbotsford    Charles      3    h  1465000.0     SP
# 2              4    Abbotsford       Park      4    h  1600000.0     VB
# 3              6    Abbotsford      Yarra      3    h  1876000.0      S
# 4              7    Abbotsford    Charles      2    h  1636000.0      S
# ...          ...           ...        ...    ...  ...        ...    ...
# 6825       13572      Watsonia    Kenmare      2    h   650000.0     PI
# 6826       13573      Werribee     Nuragi      4    h   635000.0      S
# 6827       13576  Williamstown    Merrett      3    h  1031000.0     SP
# 6828       13578  Williamstown     Verdon      4    h  2500000.0     PI
# 6829       13579    Yarraville      Agnes      4    h  1285000.0     SP
#
#             SellerG  Date  Distance  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
df_cat = df[['Suburb', 'Address', 'Type', 'Method', 'SellerG', "Date", "Regionname"]]

# %%
pd.pivot_table(df, index=['SellerG'], columns = ["Regionname"],  values = "Price")
# Out:
# Regionname             Eastern Metropolitan  Eastern Victoria  \
# SellerG
# @Realty                                 NaN               NaN
# Abercromby's                            NaN               NaN
# Alexkarbon                              NaN               NaN
# Allens                            1461400.0               NaN
# Anderson                                NaN               NaN
# ...                                     ...               ...
# hockingstuart/Village                   NaN               NaN
# iOne                                    NaN               NaN
# iProperty                          820000.0               NaN
# iSell                                   NaN               NaN
# iTRAK                              796750.0          615500.0
#
# Regionname             Northern Metropolitan  Northern Victoria  \
# SellerG
# @Realty                         4.990000e+05                NaN
# Abercromby's                    1.327500e+06                NaN
# ...

# %%
df["Address"].nunique()
# Out:
# 2876

# %%
df.drop("Address", axis = 1, inplace = True)

# %%
# Remove Suburb, SellerG, Date column
df.drop(["Suburb", "SellerG", "Date"], axis = 1, inplace = True)

# %%
df.drop(["Unnamed: 0"], axis = 1, inplace = True)
